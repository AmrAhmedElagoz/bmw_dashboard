# %%
import dash
from jupyter_dash import JupyterDash
from dash import html
from dash import dcc
from dash.dependencies import Input,Output,State

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bmw = pd.read_csv("bmw.csv")

# %%
bmw.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
bmw["engineSize"]=bmw["engineSize"].replace(0,np.nan)
bmw["tax"]=bmw["tax"].replace(0,np.nan)

# %%
bmw.dropna( inplace = True)

# %%
bmw.duplicated().sum()
# Out:
# 117

# %%
bmw.drop_duplicates(inplace=True)

# %%
a = bmw.fuelType.value_counts()
a
# Out:
# Diesel    6785
# Petrol    3337
# Hybrid     165
# Other       15
# Name: fuelType, dtype: int64

# %%
fuel=px.bar(data_frame=a,x=a.index,y=a.values,color=a.index,template="plotly_dark"
            , labels={'y': 'Total Counts','index':"Fuel"},title="Fuel Type")
fuel
# Out:
# <div>                            <div id="d09c474f-e2b8-4f01-a4b2-ce0f77deafdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d09c474f-e2b8-4f01-a4b2-ce0f77deafdd")) {                    Plotly.newPlot(                        "d09c474f-e2b8-4f01-a4b2-ce0f77deafdd",                        [{"alignmentgroup":"True","hovertemplate":"Fuel=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"Diesel","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Diesel","offsetgroup":"Diesel","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Diesel"],"xaxis":"x","y":[6785],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Fuel=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"Petrol","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Petrol","offsetgroup":"Petrol","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Petrol"],"xaxis":"x","y":[3337],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Fuel=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"Hybrid","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Hybrid","offsetgroup":"Hybrid","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Hybrid"],"xaxis":"x","y":[165],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Fuel=%{x}<br>Total Counts=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Other"],"xaxis":"x","y":[15],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"Fuel"},"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0," ...

# %%
b = bmw.transmission.value_counts()
pie= px.pie(data_frame=b,names=b.index,values=b.values,template="plotly_dark",title="Transmission Type")
pie
# Out:
# <div>                            <div id="3b6c95f3-d181-4efd-9097-4b5b6ef7e6cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b6c95f3-d181-4efd-9097-4b5b6ef7e6cc")) {                    Plotly.newPlot(                        "3b6c95f3-d181-4efd-9097-4b5b6ef7e6cc",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Semi-Auto","Automatic","Manual"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[4601,3384,2317]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"typ ...

# %%
z=bmw.model.value_counts()
z
# Out:
#  3 Series    2334
#  1 Series    1793
#  2 Series    1162
#  5 Series    1051
#  4 Series     986
#  X1           797
#  X3           550
#  X5           446
#  X2           261
#  X4           177
#  M4           122
#  6 Series     108
#  Z4           107
#  X6           106
#  7 Series     105
#  X7            55
#  8 Series      39
#  M5            29
#  M3            26
#  M2            21
#  i8            10
#  M6             8
#  Z3             7
#  i3             2
# Name: model, dtype: int64

# %%
colors = ['normal',] * len(z.index)
colors[0] = 'max'
best_sell=px.bar(data_frame=z,x=z.index,y=z.values,color=colors,color_discrete_map={"max":"red","normal":"gray"},
                 template="plotly_dark",title="Best Seller",labels={"index":"Model","y":"Selling"})
best_sell
# Out:
# <div>                            <div id="a1343231-1003-436f-b058-58844ced3f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1343231-1003-436f-b058-58844ced3f54")) {                    Plotly.newPlot(                        "a1343231-1003-436f-b058-58844ced3f54",                        [{"alignmentgroup":"True","hovertemplate":"color=max<br>Model=%{x}<br>Selling=%{y}<extra></extra>","legendgroup":"max","marker":{"color":"red","pattern":{"shape":""}},"name":"max","offsetgroup":"max","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[" 3 Series"],"xaxis":"x","y":[2334],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"color=normal<br>Model=%{x}<br>Selling=%{y}<extra></extra>","legendgroup":"normal","marker":{"color":"gray","pattern":{"shape":""}},"name":"normal","offsetgroup":"normal","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[" 1 Series"," 2 Series"," 5 Series"," 4 Series"," X1"," X3"," X5"," X2"," X4"," M4"," 6 Series"," Z4"," X6"," 7 Series"," X7"," 8 Series"," M5"," M3"," M2"," i8"," M6"," Z3"," i3"],"xaxis":"x","y":[1793,1162,1051,986,797,550,446,261,177,122,108,107,106,105,55,39,29,26,21,10,8,7,2],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"color"},"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tic ...

# %%
selling = bmw.groupby(["year","transmission","fuelType"],as_index=False).sum()
selling
# Out:
#      year transmission fuelType     price  mileage      tax      mpg  \
# 0    1996    Automatic   Petrol      5995    36000    270.0     26.4
# 1    1997       Manual   Petrol      3950    49000    270.0     35.3
# 2    1998       Manual   Petrol      3950    56500    270.0     35.3
# 3    1999    Automatic   Petrol      1200    82000    245.0     31.0
# 4    1999       Manual   Petrol     11940   184231    770.0    105.9
# ..    ...          ...      ...       ...      ...      ...      ...
# 106  2020       Manual   Diesel    883807    32783   4960.0   1860.6
# 107  2020       Manual   Petrol    737278    38312   4215.0   1336.6
# 108  2020    Semi-Auto   Diesel  11116091   531701  42590.0  14488.1
# 109  2020    Semi-Auto   Hybrid   1306073    41508   5320.0   1752.5
# 110  2020    Semi-Auto   Petrol   8787816   258440  37250.0  10218.7
#
#      engineSize
# 0           2.8
# 1           1.9
# 2           1.9
# 3           2.8
# 4           5.7
# ..          ...
# 106        67.5
# 107        44.0
# 108       687.5
# 109        74.0
# 110       547.4
#
# [111 rows x 8 columns]

# %%
px.line(selling,x='year',y="price",color="transmission",log_y=True,template="plotly_dark")
# Out:
# <div>                            <div id="bd6e728b-50ae-421d-9273-8169e0680446" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd6e728b-50ae-421d-9273-8169e0680446")) {                    Plotly.newPlot(                        "bd6e728b-50ae-421d-9273-8169e0680446",                        [{"hovertemplate":"transmission=Automatic<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Automatic","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Automatic","orientation":"v","showlegend":true,"type":"scatter","x":[1996,1999,2000,2001,2002,2003,2004,2005,2005,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2013,2014,2014,2014,2015,2015,2016,2016,2017,2017,2017,2017,2018,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[5995,1200,1550,3050,27579,18445,22695,9473,4995,4995,33479,32033,22540,42692,28005,37570,27688,123309,34993,258455,15980,628895,67035,1411324,8999,197539,2584149,19995,422674,4906739,781087,9619065,1960647,9267937,291112,251644,2444377,2960135,470286,21940,2586494,18976269,1575322,11143861,1123582,249863,1354522],"yaxis":"y"},{"hovertemplate":"transmission=Manual<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Manual","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Manual","orientation":"v","showlegend":true,"type":"scatter","x":[1997,1998,1999,2000,2001,2002,2004,2004,2005,2005,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2014,2014,2015,2015,2016,2016,2017,2017,2018,2018,2019,2019,2020,2020],"xaxis":"x","y":[3950,3950,11940,1699,5950,5340,3940,71923,4375,13498,13484,9085,8045,14670,20140,43189,48190,62450,90684,58120,120695,68924,360176,78403,1128599,341172,1248472,533691,2354258,977642,4876093,2239111,3524448,2081150,999162,1301401,4866815,5200714,883807,737278],"yaxis":"y"},{"hovertemplate":"transmission=Semi-Auto<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Semi-Auto","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Semi-Auto","orientation":"v","showlegend":true,"type":"scatter","x":[2006,2008,2009,2013,2013,2014,2014,2014,2015,2015,2016,2016,2017,2017,2017,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[12495,9495,5695,561427,233783,1369820,17999,309353,3288460,1171265,6809079,2634278,9235590,194675,4395471,6185620,106991,4526351,38696233,1170450,24028175,11116091,1306073,8787816],"yaxis":"y"}],                        {"legend":{"title":{"text":"transmission"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0 ...

# %%
px.line(selling,x='year',y="price",color="fuelType",log_y=True,template="plotly_dark")
# Out:
# <div>                            <div id="bcd82f3b-8624-4333-8eea-83d2ff0e2d80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcd82f3b-8624-4333-8eea-83d2ff0e2d80")) {                    Plotly.newPlot(                        "bcd82f3b-8624-4333-8eea-83d2ff0e2d80",                        [{"hovertemplate":"fuelType=Petrol<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Petrol","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Petrol","orientation":"v","showlegend":true,"type":"scatter","x":[1996,1997,1998,1999,1999,2000,2000,2001,2001,2002,2002,2003,2004,2004,2005,2005,2006,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2013,2014,2014,2014,2015,2015,2015,2016,2016,2016,2017,2017,2017,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[5995,3950,3950,1200,11940,1550,1699,3050,5950,27579,5340,18445,22695,71923,4995,13498,33479,9085,12495,22540,14670,28005,43189,27688,62450,34993,58120,15980,68924,67035,78403,197539,341172,233783,422674,533691,309353,781087,977642,1171265,1960647,2239111,2634278,2444377,2081150,4395471,2586494,1301401,4526351,11143861,5200714,24028175,1354522,737278,8787816],"yaxis":"y"},{"hovertemplate":"fuelType=Diesel<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Diesel","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Diesel","orientation":"v","showlegend":true,"type":"scatter","x":[2004,2005,2005,2006,2006,2007,2007,2008,2008,2008,2009,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2013,2014,2014,2014,2015,2015,2015,2016,2016,2016,2017,2017,2017,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[3940,9473,4375,4995,13484,32033,8045,42692,20140,9495,37570,48190,5695,123309,90684,258455,120695,628895,360176,1411324,1128599,561427,2584149,1248472,1369820,4906739,2354258,3288460,9619065,4876093,6809079,9267937,3524448,9235590,2960135,999162,6185620,18976269,4866815,38696233,1123582,883807,11116091],"yaxis":"y"},{"hovertemplate":"fuelType=Hybrid<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Hybrid","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Hybrid","orientation":"v","showlegend":true,"type":"scatter","x":[2013,2014,2014,2017,2017,2018,2018,2019,2019,2020,2020],"xaxis":"x","y":[8999,19995,17999,291112,194675,470286,106991,1575322,1170450,249863,1306073],"yaxis":"y"},{"hovertemplate":"fuelType=Other<br>year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"Other","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"type":"scatter","x":[2017,2018],"xaxis":"x","y":[251644,21940],"yaxis":"y"}],                        {"legend":{"title":{"text":"fuelType"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333 ...

# %%
px.line(selling,x='year',y="tax",color="transmission",log_y=True,template="plotly_dark")
# Out:
# <div>                            <div id="b5991cb6-78d6-445d-a796-e898dde41723" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5991cb6-78d6-445d-a796-e898dde41723")) {                    Plotly.newPlot(                        "b5991cb6-78d6-445d-a796-e898dde41723",                        [{"hovertemplate":"transmission=Automatic<br>year=%{x}<br>tax=%{y}<extra></extra>","legendgroup":"Automatic","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Automatic","orientation":"v","showlegend":true,"type":"scatter","x":[1996,1999,2000,2001,2002,2003,2004,2005,2005,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2013,2014,2014,2014,2015,2015,2016,2016,2017,2017,2017,2017,2018,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[270.0,245.0,270.0,325.0,1305.0,650.0,970.0,525.0,305.0,325.0,2520.0,2360.0,1075.0,1540.0,1170.0,1075.0,1310.0,2965.0,1280.0,4990.0,570.0,9235.0,1265.0,15850.0,190.0,3100.0,22830.0,195.0,6540.0,34025.0,10145.0,55950.0,18790.0,60045.0,1760.0,1915.0,17880.0,18915.0,1910.0,135.0,17070.0,82490.0,6130.0,49700.0,4495.0,825.0,5545.0],"yaxis":"y"},{"hovertemplate":"transmission=Manual<br>year=%{x}<br>tax=%{y}<extra></extra>","legendgroup":"Manual","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Manual","orientation":"v","showlegend":true,"type":"scatter","x":[1997,1998,1999,2000,2001,2002,2004,2004,2005,2005,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2014,2014,2015,2015,2016,2016,2017,2017,2018,2018,2019,2019,2020,2020],"xaxis":"x","y":[270.0,270.0,770.0,265.0,325.0,655.0,405.0,2265.0,160.0,630.0,965.0,760.0,535.0,1005.0,415.0,1820.0,1025.0,2370.0,1605.0,1935.0,1825.0,1400.0,3620.0,1540.0,8895.0,5815.0,8795.0,8700.0,11155.0,12310.0,17845.0,24030.0,25145.0,19815.0,8770.0,10705.0,30290.0,35145.0,4960.0,4215.0],"yaxis":"y"},{"hovertemplate":"transmission=Semi-Auto<br>year=%{x}<br>tax=%{y}<extra></extra>","legendgroup":"Semi-Auto","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Semi-Auto","orientation":"v","showlegend":true,"type":"scatter","x":[2006,2008,2009,2013,2013,2014,2014,2014,2015,2015,2016,2016,2017,2017,2017,2018,2018,2018,2019,2019,2019,2020,2020,2020],"xaxis":"x","y":[570.0,265.0,160.0,5830.0,3595.0,11670.0,135.0,4080.0,22340.0,13515.0,40205.0,26230.0,60555.0,1230.0,32355.0,37580.0,550.0,27285.0,173120.0,4700.0,112685.0,42590.0,5320.0,37250.0],"yaxis":"y"}],                        {"legend":{"title":{"text":"transmission"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"color ...

# %%
scatt_bmw= bmw.sort_values(by=['year'], ignore_index=True)
scatt_bmw
# Out:
#            model  year  price transmission  mileage fuelType    tax   mpg  \
# 0       5 Series  1996   5995    Automatic    36000   Petrol  270.0  26.4
# 1             Z3  1997   3950       Manual    49000   Petrol  270.0  35.3
# 2             Z3  1998   3950       Manual    56500   Petrol  270.0  35.3
# 3       3 Series  1999   1200    Automatic    82000   Petrol  245.0  31.0
# 4             Z3  1999   3995       Manual    51949   Petrol  255.0  35.3
# ...          ...   ...    ...          ...      ...      ...    ...   ...
# 10297   4 Series  2020  32995    Semi-Auto       10   Diesel  145.0  50.4
# 10298   5 Series  2020  32995    Semi-Auto       11   Hybrid  145.0  49.6
# 10299   2 Series  2020  35950    Automatic     4597   Petrol  145.0  36.2
# 10300   2 Series  2020  28950       Manual     1688   Petrol  145.0  43.5
# 10301   6 Series  2020  44950    Semi-Auto     1237   Diesel  145.0  44.1
#
#        engineSize
# 0             2.8
# 1             1.9
# 2             1.9
# 3             2.8
# 4             1.9
# ...           ...
# 10297         3.0
# 10298         2.0
# 10299         2.0
# 10300         1.5
# 10301         2.0
#
# [10302 rows x 9 columns]

# %%
test=px.scatter(bmw, x="price",y="mileage", log_x= True, symbol= 'transmission'
                , animation_frame= 'year',template="plotly_dark",
           color='transmission',hover_name='transmission',title="Price vs Mileage")
test
# Out:
# <div>                            <div id="ec56aad4-5cb9-4bfb-a3dc-7851555694ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec56aad4-5cb9-4bfb-a3dc-7851555694ed")) {                    Plotly.newPlot(                        "ec56aad4-5cb9-4bfb-a3dc-7851555694ed",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>transmission=Automatic<br>year=2014<br>price=%{x}<br>mileage=%{y}<extra></extra>","hovertext":["Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic","Automatic"],"legendgroup":"Automatic","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Automatic","orientation":"v","showlegend":true,"type":"scatter","x":[11200,14500,14000,11000,12400,15000,9900,25000,27995,10998,18998,17450,20490,15590,17080,13840,12832,17000,16500,10749,13130,18000,10970,12702,11180,13600,13950,10270,23980,26990,14790,12999,12317,13350,23557,24480,12080,10540,18712,27498,23950,23000,20450,22991,27581,11995,12995,22150,16250,9290,12300,18990,19895,14950,12950,11750,10490,13990,12490,13490,11490,11990,10990,11490,12490,10490,12490,9990,11990,13990,14490,16999,13227,13350,16999,17899,16399,13541,12523,21499,11499,12500,10230,13290,12579,10670,17000,14450,12899,12499,10999,14717,11295,10795,13000,14000,14500,12000,11000,11700,9995,16700,14990,12000,15690,13500,9500,14500,11695,1450 ...

# %%
drop_li=['price','tax']
category = ['transmission','fuelType']

# %%
app=JupyterDash(external_stylesheets=["https://codepen.io/chriddyp/pen/bWLwgP.css"])

app.layout = html.Div([
    
    html.Img(style={'margin':'30px 20px 20px 50px', 'max-width':"100px",'display': 'inline-block'},
             src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/BMW.svg/600px-BMW.svg.png"),
    
    html.Div([
             html.H1(html.B('B M W'),style={'font-family': "Verdanda",'color':'#F0A500','textAlign':'center',
                                            'margin-bottom': '1rem'}),    
             html.Span(children= ["An Overview Analysis", html.Br(), html.B('From: '), html.I('1996-2020')],
                       style={'font-family': "Arial",'color':'#F0A500','textAlign':'center', 'margin-top': '0.5rem'})     
             ],style={'display': 'inline-block','position':'absolute','width':'75%', 'margin':25, 'textAlign': 'center'}),
            
    html.Hr(),
    
    html.Div([
        html.Div([
            dcc.Graph(id = 'year', figure={}),
            dcc.Dropdown(
                id='price-tax',
                options=[{'label' : drop , 'value' : drop} for drop in drop_li],
                #multi=True,
                value='price',
                placeholder = 'Choose a continent...',
                style={ 'width': '135px',
                        'color': '#2A3F54',
                        'background-color': '#F0A500', 'textAlign': 'center'
                      
                    } 
            ),
           dcc.RadioItems(
                id='cat-radio',
                options=[
                    {'label': 'transmission', 'value': 'transmission'},
                    {'label': 'fuelType', 'value': 'fuelType'}
                        ],
                value = 'Both',
                labelStyle={'display': 'inline-block', 'color': '#F7F7F7'})
            ],style={'width': '45%', 'display': 'inline-block'}),
        
        html.Div([
            dcc.Graph(id='slide',figure=test)],style={'width': '45%', 'display': 'inline-block', 'margin-bottom': 53,
                                                      'margin':60})],
                ),
    
    html.Div([
            html.Div([dcc.Graph(id = 'fuel',figure=fuel)],style={'width': '31%', 'display': 'inline-block', 'margin':5}),
            html.Div([dcc.Graph(id='best_sell',figure=best_sell)],style={'width': '31%', 'display': 'inline-block', 'margin':5}),
            html.Div([dcc.Graph(id='pie',figure=pie)],style={'width': '31%', 'display': 'inline-block', 'margin': 5}),
            ],style={'backgroundColor':'#2A3F54'})

],style={'backgroundColor':'#2A3F54'})



@app.callback(
    Output(component_id='year', component_property='figure'),
    Input(component_id='price-tax', component_property='value'),
    Input(component_id='cat-radio', component_property='value'),
)




def update_My_Div(input_cont,input_cat):
    
    fig_= px.line(selling,x='year',y="price",color="transmission",log_y=True,template="plotly_dark",title="Year vs Price & tax")    
    if input_cont=="price" and input_cat =="transmission":
            fig_= px.line(selling,x='year',y="price",color="transmission",log_y=True,template="plotly_dark",title="Year vs Price & tax")
    elif input_cont=="tax" and input_cat =="transmission":
        fig_= px.line(selling,x='year',y="tax",color="transmission",log_y=True,template="plotly_dark",title="Year vs Price & tax")
    elif input_cont=="tax" and input_cat =="fuelType":
        fig_= px.line(selling,x='year',y="tax",color="fuelType",log_y=True,template="plotly_dark",title="Year vs Price & tax")
    else :
        fig_= px.line(selling,x='year',y="price",color="fuelType",log_y=True,template="plotly_dark",title="Year vs Price & tax")
    return fig_
app.run_server(port=8088)
# Out:
# Dash app running on http://127.0.0.1:8088/
